# %% [markdown]
# ## 4. Графические методы представления и анализа данных: гистограммы, графики «ящик с усами», диаграммы рассеяния, матрицы диаграмм рассеяния.

# %% [markdown]
# ### Гистограмма

# %%
hist(rnorm(100))
# Out:
# Plot with title “Histogram of rnorm(100)”

# %% [markdown]
# ### "Ящик с усами"
#
# Верхняя граница(ус) - это максимальное значение выборки
#
# Нижняя граница(ус) - это минимальное значение выборки
#
# Черта по середине - медианное значение выборки
#
# Верхняя граница бокса - квантиль 0.75
#
# Нижняя граница бокса - квантиль 0.25

# %%
boxplot(rnorm(100))
# Out:
# plot without title

# %% [markdown]
# ### Диаграмма рассеивания (с одним зависимым значением)

# %%
plot(InsectSprays$count)
# Out:
# plot without title

# %% [markdown]
# ### Диаграмма рассеивания (с  несколькими зависимыми значениями)

# %%
plot(iris$Sepal.Length, iris$Sepal.Width, col = iris$Species)
legend("topright", legend = levels(iris$Species), col = 1:3, pch = 21)
# Out:
# plot without title
